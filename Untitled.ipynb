# %%
from syserol.regression import patientComponents
import matplotlib.pyplot as plt

# %%
Y, Ypred = patientComponents(nComp = 20)
# Out:
# Missingness fraction: 0.29385964912280704
# Compression factor: 26.11898734177215
# Compression factor: 26.11898734177215
# 0.9619206698044882
# Compression factor: 26.11898734177215
# 0.9619206698044882
# Compression factor: 26.11898734177215
# 0.9619206698044882
# Improved decomposition on second run.
# [-2.89246590e-06  7.05848142e-07 -1.68340232e-06 -1.03037121e-05
#  -0.00000000e+00 -0.00000000e+00  1.01610555e-05  3.12835999e-06
#   0.00000000e+00  0.00000000e+00 -7.17384502e-07 -5.45556389e-07
#  -5.02568746e-06 -1.14810104e-05 -0.00000000e+00  0.00000000e+00
#  -0.00000000e+00  2.49577350e-05 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00  2.49938968e-03 -0.00000000e+00  0.00000000e+00
#  -0.00000000e+00  0.00000000e+00  0.00000000e+00  9.07171373e-03
#  -0.00000000e+00  1.46626329e-02 -0.00000000e+00  3.00838819e-02
#  -4.54068507e-03  0.00000000e+00  0.00000000e+00 -2.69143014e-03
#  -0.00000000e+00  0.00000000e+00 -0.00000000e+00  0.00000000e+00
# ...

# %%
plt.plot(Y, Ypred, '.');
plt.ylabel("Predicted");
